# %% [markdown]
# <a href="https://colab.research.google.com/github/jgraving/deepposekit/blob/master/examples/step1_create_annotation_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DeepPoseKit Step 1 - Create an annotation set
#
# This is step 1 of the example notebooks for using DeepPoseKit. This notebook shows you how to load and sample images from a video, define a keypoint skeleton, and save the data to a file for labelling with keypoints.
#
#
# **NOTE**: If you run into problems, you can help us improve DeepPoseKit by [opening an issue](https://github.com/jgraving/deepposekit/issues/new) or [submitting a pull request](https://help.github.com/en/articles/creating-a-pull-request-from-a-fork)

# %% [markdown]
# If you haven't already installed DeepPoseKit you can run the next cell

# %%
import numpy as np
import sys
import cv2
import h5py
import matplotlib.pyplot as plt
from deepposekit.io import VideoReader, DataGenerator, initialize_dataset
from deepposekit.annotate import KMeansSampler
import tqdm
import glob
import pandas as pd

from os.path import expanduser

#try:
#    import google.colab
#    IN_COLAB = True
#except:
#    IN_COLAB = False

HOME = '/home/mithrandir/Downloads'
# Out:
# 2024-02-15 02:54:20.738909: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-15 02:54:20.738932: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-15 02:54:20.739419: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-15 02:54:20.742454: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-15 02:54:21.246816: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Use the next cell to download the example data into your home directory

# %% [markdown]
# # A note on image resolutions
#
# Currently DeepPoseKit only supports image resolutions that can be repeatedly divided by 2. For example, all of these values are valid image resolutions for either height or width:

# %%
exp = np.arange(1,12)
exp = 2**exp

print(1*exp)
print(3*exp)
print(5*exp)
print(7*exp)
print(11*exp)
# Out:
# [   2    4    8   16   32   64  128  256  512 1024 2048]
# [   6   12   24   48   96  192  384  768 1536 3072 6144]
# [   10    20    40    80   160   320   640  1280  2560  5120 10240]
# [   14    28    56   112   224   448   896  1792  3584  7168 14336]
# [   22    44    88   176   352   704  1408  2816  5632 11264 22528]

# %% [markdown]
# Images that do not match these resolutions must be manually resized, cropped, or padded. We are working to add automated image size adjustments.

# %% [markdown]
# # Open a video
# The `VideoReader` class allows you to load in single video frames or batches of frames from nearly any video format.

# %%
videos = glob.glob(HOME + '/deepposekit-data/datasets/fly/*.avi')
videos
# Out:
# ['/home/mithrandir/Downloads/deepposekit-data/datasets/fly/video.avi']

# %%
reader = VideoReader(HOME + '/deepposekit-data/datasets/fly/video.avi', gray=True)
frame = reader[0] # read a frame
reader.close()
frame.shape
# Out:
# (1, 192, 192, 1)

# %%
print(reader)
print(type(reader), len(reader))

### 18 mins 45 seconds video at 30 fps
### total frames in that video is: 33749
# Out:
# < cv2.VideoCapture 0x7f03c5480580>
# <class 'deepposekit.io.video.VideoReader'> 33749

# %%
plt.figure(figsize=(5,5))
plt.imshow(frame[0,...,0])
plt.show()

# %% [markdown]
# # Sample video frames
# This loads batches of 100 frames from the video, and then randomly samples frames from the batches to hold them in memory. You can use any method for sampling frames.

# %%
reader = VideoReader(HOME + '/deepposekit-data/datasets/fly/video.avi', batch_size=100, gray=True)
print(type(reader))
print(len(reader))
# Out:
# <class 'deepposekit.io.video.VideoReader'>
# 338

# %%
reader = VideoReader(HOME + '/deepposekit-data/datasets/fly/video.avi', batch_size=100, gray=True)

randomly_sampled_frames = []
for idx in tqdm.tqdm(range(len(reader)-1)):
    batch = reader[idx]
    random_sample = batch[np.random.choice(batch.shape[0], 10, replace=False)]
    randomly_sampled_frames.append(random_sample)
reader.close()
print(len(randomly_sampled_frames))
#print(randomly_sampled_frames)
randomly_sampled_frames = np.concatenate(randomly_sampled_frames)
randomly_sampled_frames.shape
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 337/337 [00:01<00:00, 227.68it/s]
# 337
# (3370, 192, 192, 1)

# %% [markdown]
# # Apply k-means to reduce correlation
#
# This applies the k-means algorithm to the images using `KMeansSampler` to even out sampling across the distribution of images and reduce correlation within the annotation set.

# %%
kmeans = KMeansSampler(n_clusters=10, max_iter=1000, n_init=10, batch_size=100, verbose=True)
kmeans.fit(randomly_sampled_frames)
# Out:
# Init 1/10 with method k-means++
# Inertia for init 1/10: 5064443120.0
# Init 2/10 with method k-means++
# Inertia for init 2/10: 4286070957.0
# Init 3/10 with method k-means++
# Inertia for init 3/10: 4140054017.0
# Init 4/10 with method k-means++
# Inertia for init 4/10: 4454778907.0
# Init 5/10 with method k-means++
# Inertia for init 5/10: 4630853307.0
# Init 6/10 with method k-means++
# Inertia for init 6/10: 4659824398.0
# Init 7/10 with method k-means++
# Inertia for init 7/10: 4559886113.0
# Init 8/10 with method k-means++
# Inertia for init 8/10: 4506005357.0
# Init 9/10 with method k-means++
# Inertia for init 9/10: 4172593987.0
# Init 10/10 with method k-means++
# Inertia for init 10/10: 4264037356.0
# Minibatch step 1/33700: mean batch inertia: 13782151.41
# Minibatch step 2/33700: mean batch inertia: 10205076.127069201, ewa inertia: 10205076.127069201
# Minibatch step 3/33700: mean batch inertia: 9414162.815498518, ewa inertia: 10158151.575804256
# Minibatch step 4/33700: mean batch inertia: 9182963.523227412, ewa inertia: 10100294.08232595
# Minibatch step 5/33700: mean batch inertia: 9270429.391839659, ewa inertia: 10051058.562273368
# Minibatch step 6/33700: mean batch inertia: 9618995.166421631, ewa inertia: 10025424.424281573
# Minibatch step 7/33700: mean batch inertia: 9056367.325624814, ewa inertia: 9967930.677698556
# Minibatch step 8/33700: mean batch inertia: 8946980.349312048, ewa inertia: 9907358.127809117
# Minibatch step 9/33700: mean batch inertia: 9211762.972523516, ewa inertia: 9866088.762321986
# Minibatch step 10/33700: mean batch inertia: 9047851.21261297, ewa inertia: 9817543.07559941
# Minibatch step 11/33700: mean batch inertia: 8735918.944639899, ewa inertia: 9753370.774741534
# Minibatch step 12/33700: mean batch inertia: 9167228.767353473, ewa inertia: 9718595.218088431
# Minibatch step 13/33700: mean batch inertia: 8875807.86113519, ewa inertia: 9668593.001716243
# Minibatch step 14/33700: mean batch inertia: 8566199.48914053, ewa inertia: 9603188.462257583
# Minibatch step 15/33700: mean batch inertia: 9192617.49956508, ewa inertia: 9578829.461207895
# Minibatch step 16/33700: mean batch inertia: 8696551.180065822, ewa inertia: 9526484.265055887
# Minibatch step 17/33700: mean batch inertia: 8601962.08009158, ewa inertia: 9471632.756010246
# Minibatch step 18/33700: mean batch inertia: 8762471.60552696, ewa inertia: 9429558.525782818
# Minibatch step 19/33700: mean batch inertia: 8655202.272720942, ewa inertia: 9383616.297775587
# Minibatch step 20/33700: mean batch inertia: 8977833.67600941, ewa inertia: 9359541.386961812
# Minibatch step 21/33700: mean batch inertia: 9028645.914357614, ewa inertia: 9339909.498940205
# Minibatch step 22/33700: mean batch inertia: 8628843.506236289, ewa inertia: 9297722.255231876
# Minibatch step 23/33700: mean batch inertia: 9338509.468190148, ewa inertia: 9300142.143274492
# Minibatch step 24/33700: mean batch inertia: 8946820.706860473, ewa inertia: 9279179.732333288
# Minibatch step 25/33700: mean batch inertia: 8644454.428383786, ewa inertia: 9241521.749304542
# Minibatch step 26/33700: mean batch inertia: 9068255.063568484, ewa inertia: 9231241.91034067
# Minibatch step 27/33700: mean batch inertia: 8893135.790982848, ewa inertia: 9211182.217705974
# Minibatch step 28/33700: mean batch inertia: 9044679.615588577, ewa inertia: 9201303.68895383
# Minibatch step 29/33700: mean batch inertia: 8912915.135286057, ewa inertia: 9184193.718401011
# Minibatch step 30/33700: mean batch inertia: 8874403.876695327, ewa inertia: 9165814.018507468
# Minibatch step 31/33700: mean batch inertia: 9019761.490980245, ewa inertia: 9157148.784005703
# Minibatch step 32/33700: mean batch inertia: 8661684.81701093, ewa inertia: 9127753.117022922
# Minibatch step 33/33700: mean batch inertia: 9063637.891403181, ewa inertia: 9123949.187884998
# Minibatch step 34/33700: mean batch inertia: 8982126.554382352, ewa inertia: 9115534.911201363
# Minibatch step 35/33700: mean batch inertia: 8263803.828188829, ewa inertia: 9065002.067356063
# Minibatch step 36/33700: mean batch inertia: 8651702.285943897, ewa inertia: 9040481.16664932
# Minibatch step 37/33700: mean batch inertia: 9014513.652079921, ewa inertia: 9038940.525025506
# Minibatch step 38/33700: mean batch inertia: 8724141.555789508, ewa inertia: 9020263.635720493
# Minibatch step 39/33700: mean batch inertia: 8792896.377376977, ewa inertia: 9006774.032733634
# Minibatch step 40/33700: mean batch inertia: 9030449.95082838, ewa inertia: 9008178.714910718
# Minibatch step 41/33700: mean batch inertia: 9073782.73809481, ewa inertia: 9012070.973776579
# Minibatch step 42/33700: mean batch inertia: 8960906.694477165, ewa inertia: 9009035.418789964
# Minibatch step 43/33700: mean batch inertia: 8040805.380572452, ewa inertia: 8951590.741351964
# Minibatch step 44/33700: mean batch inertia: 9463530.55716471, ewa inertia: 8981963.913455954
# Minibatch step 45/33700: mean batch inertia: 8915672.085883586, ewa inertia: 8978030.847447507
# Minibatch step 46/33700: mean batch inertia: 9029111.121523004, ewa inertia: 8981061.418439824
# Minibatch step 47/33700: mean batch inertia: 9011669.300422098, ewa inertia: 8982877.37109377
# Minibatch step 48/33700: mean batch inertia: 8937566.925060306, ewa inertia: 8980189.12155159
# Minibatch step 49/33700: mean batch inertia: 8872495.679267336, ewa inertia: 8973799.715305122
# Minibatch step 50/33700: mean batch inertia: 8609657.334473288, ewa inertia: 8952195.302321922
# Minibatch step 51/33700: mean batch inertia: 8924389.340362875, ewa inertia: 8950545.586394362
# Minibatch step 52/33700: mean batch inertia: 8469051.559219642, ewa inertia: 8921978.750014966
# Minibatch step 53/33700: mean batch inertia: 8915029.661575336, ewa inertia: 8921566.463545691
# Minibatch step 54/33700: mean batch inertia: 8727519.205471229, ewa inertia: 8910053.722040236
# Minibatch step 55/33700: mean batch inertia: 8801214.123603432, ewa inertia: 8903596.314835442
# Minibatch step 56/33700: mean batch inertia: 9127895.212181699, ewa inertia: 8916903.873265954
# Minibatch step 57/33700: mean batch inertia: 9147003.685609315, ewa inertia: 8930555.597522458
# Minibatch step 58/33700: mean batch inertia: 8451288.872735208, ewa inertia: 8902120.906048875
# Minibatch step 59/33700: mean batch inertia: 8777735.839797812, ewa inertia: 8894741.19283315
# Minibatch step 60/33700: mean batch inertia: 8486271.561073922, ewa inertia: 8870506.862856334
# Minibatch step 61/33700: mean batch inertia: 8713362.424265945, ewa inertia: 8861183.549976453
# Minibatch step 62/33700: mean batch inertia: 8885545.625076512, ewa inertia: 8862628.94155759
# Minibatch step 63/33700: mean batch inertia: 8859198.205784196, ewa inertia: 8862425.397459494
# Minibatch step 64/33700: mean batch inertia: 8705026.066564577, ewa inertia: 8853086.961927313
# Minibatch step 65/33700: mean batch inertia: 9120467.782052476, ewa inertia: 8868950.552560667
# Minibatch step 66/33700: mean batch inertia: 8670629.494760688, ewa inertia: 8857184.24833047
# Minibatch step 67/33700: mean batch inertia: 9270366.601956658, ewa inertia: 8881698.182096487
# Minibatch step 68/33700: mean batch inertia: 9173421.615262395, ewa inertia: 8899006.009635255
# Minibatch step 69/33700: mean batch inertia: 9141273.743875545, ewa inertia: 8913379.65153619
# Minibatch step 70/33700: mean batch inertia: 9058544.768283928, ewa inertia: 8921992.236332852
# Minibatch step 71/33700: mean batch inertia: 9085467.221264634, ewa inertia: 8931691.137841709
# Minibatch step 72/33700: mean batch inertia: 8996828.988983735, ewa inertia: 8935555.738918068
# Minibatch step 73/33700: mean batch inertia: 9179158.86323735, ewa inertia: 8950008.60894591
# Minibatch step 74/33700: mean batch inertia: 8503082.576931497, ewa inertia: 8923492.67705541
# Converged (lack of improvement in inertia) at step 74/33700
# KMeansSampler(max_iter=1000, n_init=10, verbose=True)

# %%
kmeans.plot_centers(n_rows=2)
plt.show()

# %%
kmeans_sampled_frames, kmeans_cluster_labels = kmeans.sample_data(randomly_sampled_frames, n_samples_per_label=10)
kmeans_sampled_frames.shape
# Out:
# (100, 192, 192, 1)

# %% [markdown]
# # Define a keypoints skeleton file
# You must create a .xlsx or .csv file with keypoint names, parent relationships, and swapping relationships for bilaterally symmetric parts (only relevant if using flipping augmentations). If you leave out the `parent` and `swap` columns, then these will simply not be used for annotating data and training the model.
#
# See example skeleton.csv files for more details

# %%
skeleton = pd.read_csv(HOME + '/deepposekit-data/datasets/fly/skeleton.csv')
skeleton
# Out:
#          name     parent       swap
# 0        head        NaN        NaN
# 1        eyeL       head       eyeR
# 2        eyeR       head       eyeL
# 3        neck       head        NaN
# 4      thorax       neck        NaN
# 5     abdomen     thorax        NaN
# 6   forelegR1        NaN  forelegL1
# 7   forelegR2  forelegR1  forelegL2
# 8   forelegR3  forelegR2  forelegL3
# 9   forelegR4  forelegR3  forelegL4
# 10   midlegR1        NaN   midlegL1
# 11   midlegR2   midlegR1   midlegL2
# 12   midlegR3   midlegR2   midlegL2
# 13   midlegR4   midlegR3   midlegL4
# 14  hindlegR1        NaN  hindlegL1
# 15  hindlegR2  hindlegR1  hindlegL2
# 16  hindlegR3  hindlegR2  hindlegL3
# 17  hindlegR4  hindlegR3  hindlegL4
# 18  forelegL1        NaN  forelegR1
# 19  forelegL2  forelegL1  forelegR2
# 20  forelegL3  forelegL2  forelegR3
# 21  forelegL4  forelegL3  forelegR4
# 22   midlegL1        NaN   midlegR1
# 23   midlegL2   midlegL1   midlegR2
# 24   midlegL3   midlegL2   midlegR3
# 25   midlegL4   midlegL3   midlegR4
# 26  hindlegL1        NaN  hindlegR1
# 27  hindlegL2  hindlegL1  hindlegR2
# 28  hindlegL3  hindlegL2  hindlegR3
# 29  hindlegL4  hindlegL3  hindlegR4
# 30      wingL       neck      wingR
# 31      wingR       neck      wingL

# %% [markdown]
# # Initialize a new data set for annotations
#
# You can use any method for sampling images to create a numpy array with the shape (n_images, height, width, channels) and then initialize an annotation set. Check the doc string for more details:

# %%
#initialize_dataset?

# %%
initialize_dataset(
    images=kmeans_sampled_frames,
    datapath=HOME + '/deepposekit-data/datasets/fly/example_annotation_set.h5',
    skeleton=HOME + '/deepposekit-data/datasets/fly/skeleton.csv',
    overwrite=False # This overwrites the existing datapath
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 initialize_dataset(
#       2     images=kmeans_sampled_frames,
#       3     datapath=HOME + '/deepposekit-data/datasets/fly/example_annotation_set.h5',
#       4     skeleton=HOME + '/deepposekit-data/datasets/fly/skeleton.csv',
#       5     overwrite=False # This overwrites the existing datapath
#       6 )
#
# File ~/anaconda3/envs/dpk/lib/python3.10/site-packages/deepposekit/io/utils.py:107, in initialize_dataset(datapath, images, skeleton, keypoints, dataset, overwrite)
#      81 """
#      82 Intialize an image dataset for annotation as an h5 file
#      83
#    (...)
#     104     Whether to overwrite an existing .h5 file with the same name.
#     105 """
#     106 if os.path.exists(datapath) and overwrite is False:
# --> 107     raise OSError(
#     108         "Annotation set {} already exists. Delete the file or set `overwrite=True`.".format(
#     109             datapath
#     110         )
#     111     )
#     112 if not isinstance(images, np.ndarray):
#     113     raise TypeError(
#     114         "images must be ndarray with shape (n_images, height, width, channels)"
#     115     )
#
# OSError: Annotation set /home/mithrandir/Downloads/deepposekit-data/datasets/fly/example_annotation_set.h5 already exists. Delete the file or set `overwrite=True`.

# %% [markdown]
# # Create a data generator
# This creates a `DataGenerator` for loading annotated data. Indexing the generator returns an image-keypoints pair, which you can then visualize. Right now all the keypoints are set to zero, because they haven't been annotated.
#
# You can also look at the doc string for more explanation:

# %%
#DataGenerator?

# %%
data_generator = DataGenerator(HOME + '/deepposekit-data/datasets/fly/example_annotation_set.h5', mode="full")

image, keypoints = data_generator[0]

plt.figure(figsize=(5,5))
image = image[0] if image.shape[-1] is 3 else image[0, ..., 0]
cmap = None if image.shape[-1] is 3 else 'gray'
plt.imshow(image, cmap=cmap, interpolation='none')
for idx, jdx in enumerate(data_generator.graph):
    if jdx > -1:
        plt.plot(
            [keypoints[0, idx, 0], keypoints[0, jdx, 0]],
            [keypoints[0, idx, 1], keypoints[0, jdx, 1]],
            'r-'
        )
plt.scatter(keypoints[0, :, 0], keypoints[0, :, 1], c=np.arange(data_generator.keypoints_shape[0]), s=50, cmap=plt.cm.hsv, zorder=3)

plt.show()
# Out:
# <>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /tmp/ipykernel_24165/2908463215.py:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   image = image[0] if image.shape[-1] is 3 else image[0, ..., 0]
# /tmp/ipykernel_24165/2908463215.py:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   cmap = None if image.shape[-1] is 3 else 'gray'
